# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cleaned.csv')
df.head()
# Out:
#        name  stars  planets  moon  discoverymethod  disc_year  \
# 0  11 Com b      2        1     0  Radial Velocity       2007
# 1  11 Com b      2        1     0  Radial Velocity       2007
# 2  11 UMi b      1        1     0  Radial Velocity       2009
# 3  11 UMi b      1        1     0  Radial Velocity       2009
# 4  11 UMi b      1        1     0  Radial Velocity       2009
#
#                   disc_telescope             disc_instrument  pul_flag  \
# 0               2.16 m Telescope  Coude Echelle Spectrograph         0
# 1               2.16 m Telescope  Coude Echelle Spectrograph         0
# 2  2.0 m Alfred Jensch Telescope  Coude Echelle Spectrograph         0
# 3  2.0 m Alfred Jensch Telescope  Coude Echelle Spectrograph         0
# 4  2.0 m Alfred Jensch Telescope  Coude Echelle Spectrograph         0
#
#    ptv_flag  ...  dkin_flag  pl_controv_flag  orbital_period  radius(earth)  \
# 0         0  ...          0                0       326.03000            NaN
# ...

# %%
df.describe()
# Out:
#               stars       planets     moon     disc_year      pul_flag  \
# count  34084.000000  34084.000000  34084.0  34084.000000  34084.000000
# mean       1.080712      1.861079      0.0   2015.124956      0.000352
# std        0.299877      1.191359      0.0      3.615156      0.018761
# min        1.000000      1.000000      0.0   1992.000000      0.000000
# 25%        1.000000      1.000000      0.0   2014.000000      0.000000
# 50%        1.000000      1.000000      0.0   2016.000000      0.000000
# 75%        1.000000      2.000000      0.0   2016.000000      0.000000
# max        4.000000      8.000000      0.0   2023.000000      1.000000
#
#            ptv_flag     tran_flag      ast_flag      obm_flag    micro_flag  \
# count  34084.000000  34084.000000  34084.000000  34084.000000  34084.000000
# mean       0.000059      0.916060      0.002347      0.011149      0.015931
# std        0.007660      0.277301      0.048391      0.105000      0.125211
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34084 entries, 0 to 34083
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             34084 non-null  object
#  1   stars            34084 non-null  int64
#  2   planets          34084 non-null  int64
#  3   moon             34084 non-null  int64
#  4   discoverymethod  34084 non-null  object
#  5   disc_year        34084 non-null  int64
#  6   disc_telescope   34084 non-null  object
#  7   disc_instrument  34084 non-null  object
#  8   pul_flag         34084 non-null  int64
#  9   ptv_flag         34084 non-null  int64
#  10  tran_flag        34084 non-null  int64
#  11  ast_flag         34084 non-null  int64
#  12  obm_flag         34084 non-null  int64
#  13  micro_flag       34084 non-null  int64
#  14  etv_flag         34084 non-null  int64
#  15  ima_flag         34084 non-null  int64
#  16  dkin_flag        34084 non-null  int64
# ...

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# name                0.000000
# stars               0.000000
# planets             0.000000
# moon                0.000000
# discoverymethod     0.000000
# disc_year           0.000000
# disc_telescope      0.000000
# disc_instrument     0.000000
# pul_flag            0.000000
# ptv_flag            0.000000
# tran_flag           0.000000
# ast_flag            0.000000
# obm_flag            0.000000
# micro_flag          0.000000
# etv_flag            0.000000
# ima_flag            0.000000
# dkin_flag           0.000000
# pl_controv_flag     0.000000
# orbital_period      8.775378
# radius(earth)      31.046825
# mass(earth)        90.502875
# eccentricity       50.146696
# eq_temp            54.503579
# st_efftemp          7.431639
# st_age             79.905528
# sy_keplermag       16.735125
# dtype: float64

# %%
df['stars'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='stars'>

# %%
df.iloc[:,8:18].columns
# Out:
# Index(['pul_flag', 'ptv_flag', 'tran_flag', 'ast_flag', 'obm_flag',
#        'micro_flag', 'etv_flag', 'ima_flag', 'dkin_flag', 'pl_controv_flag'],
#       dtype='object')
